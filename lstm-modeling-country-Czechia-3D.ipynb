# %%
############################ Packages
import os
import pandas as pd
import numpy as np
import datetime
from matplotlib import pyplot
import seaborn as sns
import sys 
from scipy.stats import randint
 
from sklearn.model_selection import train_test_split # to split the data into two parts
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline # pipeline making
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics # for the check the error and accuracy of the model
from sklearn.metrics import mean_squared_error,r2_score

## for Deep-learing:
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout

import warnings
warnings.filterwarnings("ignore")

# %%
orders_initial =pd.read_csv('data\df_merged.csv'  , parse_dates=['date'] )
orders_initial.head()
# Out:
#         date   item_code  quantity  unit_price_vat_excl         site  \
# 0 2019-06-01  ZB00023833         1            22.326744    top4sport
# 1 2019-06-01  ZB00000154         1            10.378682  top4running
# 2 2019-06-01  ZB00007330         1            14.959302  top4running
# 3 2019-06-01  ZB00018948         1            25.594186  top4running
# 4 2019-06-01  ZB00022416         1            28.797674  top4running
#
#   country_code    brand_name   group0    group1  group2  ...  country  \
# 0           CZ  Under Armour  Apparel     Pants  Shorts  ...  Czechia
# 1           CZ          Nike  Apparel  T-Shirts     NaN  ...  Czechia
# 2           CZ          Nike  Apparel  T-Shirts     NaN  ...  Czechia
# 3           CZ          Nike  Apparel  T-Shirts    Tank  ...  Czechia
# 4           CZ          Nike  Apparel     Pants  Shorts  ...  Czechia
#
#   temperature Weather_Condition  sale_amnt month  year_month  year_week  \
# 0        19.0            Cloudy  22.326744     6     2019-06    2019-21
# 1        19.0            Cloudy  10.378682     6     2019-06    2019-21
# 2        19.0            Cloudy  14.959302     6     2019-06    2019-21
# 3        19.0            Cloudy  25.594186     6     2019-06    2019-21
# 4        19.0            Cloudy  28.797674     6     2019-06    2019-21
#
#   weekday yearweek  yearday
# 0       5       21      152
# 1       5       21      152
# 2       5       21      152
# 3       5       21      152
# 4       5       21      152
#
# [5 rows x 22 columns]

# %%
orders = orders_initial[['date','quantity','unit_price_vat_excl','weekday','month','year_month','year_week','yearweek','yearday','brand_name','group0','group1',
                         'category','country','temperature']].sort_values('date')

orders.head()
# Out:
#          date  quantity  unit_price_vat_excl  weekday  month year_month  \
# 0  2019-06-01         1            22.326744        5      6    2019-06
# 96 2019-06-01         3            26.010465        5      6    2019-06
# 95 2019-06-01         1             2.405061        5      6    2019-06
# 94 2019-06-01         2            13.628631        5      6    2019-06
# 93 2019-06-01         1             2.405061        5      6    2019-06
#
#    year_week  yearweek  yearday         brand_name     group0 group1  \
# 0    2019-21        21      152       Under Armour    Apparel  Pants
# 96   2019-21        21      152             adidas  Equipment  Balls
# 95   2019-21        21      152  - žádný výrobce -      Other    NaN
# 94   2019-21        21      152               Nike    Apparel  Pants
# 93   2019-21        21      152  - žádný výrobce -      Other    NaN
#
#     category  country  temperature
# 0    fitness  Czechia         19.0
# 96  football  Czechia         19.0
# 95       NaN  Hungary         19.0
# 94   running  Hungary         19.0
# 93       NaN  Hungary         19.0

# %%
# Calculate daily Quantities
result = pd.DataFrame(orders.groupby(['date','year_month' ,'yearday' , 'weekday','country' ], as_index=False).agg({ 'temperature':'mean' , 'quantity': 'sum'  }))

######## Select Country
dataset = result[result['country'] == 'Czechia']
dataset = dataset.drop(columns = ['country'])

# %%
dataset.head()
# Out:
#          date year_month  yearday  weekday  temperature  quantity
# 0  2019-06-01    2019-06      152        5         19.0        99
# 6  2019-06-02    2019-06      153        6         21.0         5
# 7  2019-06-03    2019-06      154        0         21.0        42
# 10 2019-06-04    2019-06      155        1         22.0      1142
# 15 2019-06-05    2019-06      156        2         22.0      1717

# %%
dataset.set_index('date' , inplace=True )
dataset.head()
# Out:
#            year_month  yearday  weekday  temperature  quantity
# date
# 2019-06-01    2019-06      152        5         19.0        99
# 2019-06-02    2019-06      153        6         21.0         5
# 2019-06-03    2019-06      154        0         21.0        42
# 2019-06-04    2019-06      155        1         22.0      1142
# 2019-06-05    2019-06      156        2         22.0      1717

# %%
#dataset=dataset[['quantity','temperature']].resample('W').agg(['sum','mean'])
q=pd.DataFrame(dataset.quantity.resample('3D').agg('sum'))
t=pd.DataFrame(dataset.temperature.resample('3D').agg('mean'))
yw=pd.DataFrame(dataset.yearday.resample('3D').agg('mean'))
print(q.head())
print(t.head())
print(yw.head())
# Out:
#             quantity
# date
# 2019-06-01       146
# 2019-06-04      3366
# 2019-06-07       278
# 2019-06-10      1935
# 2019-06-13       786
#             temperature
# date
# 2019-06-01    20.333333
# 2019-06-04    21.333333
# 2019-06-07    17.500000
# 2019-06-10    23.666667
# 2019-06-13    21.000000
#             yearday
# date
# 2019-06-01    153.0
# 2019-06-04    156.0
# 2019-06-07    158.5
# 2019-06-10    162.0
# 2019-06-13    164.5

# %%
#df_merged = df_orders.merge(df_items, on='item_code', how='left') 
dataset =      yw.merge(t, on='date', how='left') 
dataset = dataset.merge(q, on='date', how='left') 
dataset.head()
# Out:
#             yearday  temperature  quantity
# date
# 2019-06-01    153.0    20.333333       146
# 2019-06-04    156.0    21.333333      3366
# 2019-06-07    158.5    17.500000       278
# 2019-06-10    162.0    23.666667      1935
# 2019-06-13    164.5    21.000000       786

# %%
dataset.reset_index('date' , inplace=True)
dataset.head()
# Out:
#         date  yearday  temperature  quantity
# 0 2019-06-01    153.0    20.333333       146
# 1 2019-06-04    156.0    21.333333      3366
# 2 2019-06-07    158.5    17.500000       278
# 3 2019-06-10    162.0    23.666667      1935
# 4 2019-06-13    164.5    21.000000       786

# %%
pyplot.figure(figsize=(10,8))
pyplot.subplot(2, 1, 1)
pyplot.plot(dataset['date'],dataset['quantity'])
pyplot.xticks(rotation = 0, size=10)
pyplot.yticks( size=10)
pyplot.xlabel('Date') 
pyplot.ylabel('Quantity') 
pyplot.ylim(0000,8000)
pyplot.show()

pyplot.figure(figsize=(10,8))
pyplot.subplot(2, 1, 2)
pyplot.plot(dataset['date'],dataset['temperature'])
pyplot.xticks(rotation = 0, size=10)
pyplot.yticks( size=10)
pyplot.xlabel('Date') 
pyplot.ylabel('temperature') 
pyplot.ylim(-10,30)
pyplot.show()

# %%
problem_description = 'Problem'

# specify the number of lag hours
n_lag = 1
n_lead = 5

# %%
############################### LSTM

from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
 # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
 # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
# put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
# drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
dataset.head()
# Out:
#         date  yearday  temperature  quantity
# 0 2019-06-01    153.0    20.333333       146
# 1 2019-06-04    156.0    21.333333      3366
# 2 2019-06-07    158.5    17.500000       278
# 3 2019-06-10    162.0    23.666667      1935
# 4 2019-06-13    164.5    21.000000       786

# %%
df=dataset.iloc[:,1:]
print(df.shape)
df.head()
# Out:
# (320, 3)
#    yearday  temperature  quantity
# 0    153.0    20.333333       146
# 1    156.0    21.333333      3366
# 2    158.5    17.500000       278
# 3    162.0    23.666667      1935
# 4    164.5    21.000000       786

# %%
# load dataset
values = df.values
# integer encode direction
### encoder = LabelEncoder()
### values[:,4] = encoder.fit_transform(values[:,4])

# ensure all data is float
values = values.astype('float32')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

n_features = values.shape[1]
# frame as supervised learning
reframed = series_to_supervised(scaled, n_lag, n_lead+1 )
print(reframed.shape)

reframed.head()
# Out:
# (314, 21)
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)  var1(t+1)  \
# 1   0.417127   0.873786   0.000000  0.425414  0.902913  0.493714   0.432320
# 2   0.425414   0.902913   0.493714  0.432320  0.791262  0.020239   0.441989
# 3   0.432320   0.791262   0.020239  0.441989  0.970874  0.274302   0.448895
# 4   0.441989   0.970874   0.274302  0.448895  0.893204  0.098129   0.458564
# 5   0.448895   0.893204   0.098129  0.458564  0.834952  0.286109   0.466851
#
#    var2(t+1)  var3(t+1)  var1(t+2)  ...  var3(t+2)  var1(t+3)  var2(t+3)  \
# 1   0.791262   0.020239   0.441989  ...   0.274302   0.448895   0.893204
# 2   0.970874   0.274302   0.448895  ...   0.098129   0.458564   0.834952
# 3   0.893204   0.098129   0.458564  ...   0.286109   0.466851   0.902913
# 4   0.834952   0.286109   0.466851  ...   0.151947   0.475138   0.883495
# 5   0.902913   0.151947   0.475138  ...   0.177706   0.483425   1.000000
#
#    var3(t+3)  var1(t+4)  var2(t+4)  var3(t+4)  var1(t+5)  var2(t+5)  var3(t+5)
# 1   0.098129   0.458564   0.834952   0.286109   0.466851   0.902913   0.151947
# 2   0.286109   0.466851   0.902913   0.151947   0.475138   0.883495   0.177706
# 3   0.151947   0.475138   0.883495   0.177706   0.483425   1.000000   0.187826
# 4   0.177706   0.483425   1.000000   0.187826   0.491713   0.912621   0.121895
# 5   0.187826   0.491713   0.912621   0.121895   0.500000   0.873786   0.266023
#
# [5 rows x 21 columns]

# %%
values.shape[1]
# Out:
# 3

# %%
# split into train and test sets
values = reframed.values

n_train = int(values.shape[0]*0.8)

train = values[:n_train, :]
test = values[n_train:, :]

# split into input and outputs
n_obs = ( n_lag +1 ) * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X,  test_y  =  test[:, :n_obs],  test[:, -1]
print('train: ', train_X.shape,  train_y.shape)
print('test : ',test_X.shape,  test_y.shape)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_lag + 1 , n_features))
test_X = test_X.reshape((test_X.shape[0], n_lag + 1, n_features))
print('train: ', train_X.shape, train_y.shape)
print('test : ', test_X.shape, test_y.shape)
# Out:
# train:  (251, 6) (251,)
# test :  (63, 6) (63,)
# train:  (251, 2, 3) (251,)
# test :  (63, 2, 3) (63,)

# %%
# design network 
model = Sequential()
model.add(LSTM(70, return_sequences=True , input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(70))
model.add(Dropout(0.1))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# fit network
n_epochs=100
history = model.fit(train_X, train_y, epochs=n_epochs, batch_size=50, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.ylim(0,.04)
pyplot.xlabel('Epoch') 
pyplot.ylabel('Loss') 
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# 6/6 - 6s - loss: 0.1110 - val_loss: 0.1554 - 6s/epoch - 1s/step
# Epoch 2/100
# 6/6 - 0s - loss: 0.0627 - val_loss: 0.0903 - 84ms/epoch - 14ms/step
# Epoch 3/100
# 6/6 - 0s - loss: 0.0318 - val_loss: 0.0507 - 87ms/epoch - 15ms/step
# Epoch 4/100
# 6/6 - 0s - loss: 0.0260 - val_loss: 0.0428 - 83ms/epoch - 14ms/step
# Epoch 5/100
# 6/6 - 0s - loss: 0.0276 - val_loss: 0.0440 - 84ms/epoch - 14ms/step
# Epoch 6/100
# 6/6 - 0s - loss: 0.0266 - val_loss: 0.0489 - 88ms/epoch - 15ms/step
# Epoch 7/100
# 6/6 - 0s - loss: 0.0265 - val_loss: 0.0535 - 85ms/epoch - 14ms/step
# Epoch 8/100
# 6/6 - 0s - loss: 0.0262 - val_loss: 0.0527 - 85ms/epoch - 14ms/step
# Epoch 9/100
# 6/6 - 0s - loss: 0.0251 - val_loss: 0.0487 - 90ms/epoch - 15ms/step
# Epoch 10/100
# 6/6 - 0s - loss: 0.0240 - val_loss: 0.0447 - 85ms/epoch - 14ms/step
# Epoch 11/100
# 6/6 - 0s - loss: 0.0238 - val_loss: 0.0431 - 85ms/epoch - 14ms/step
# Epoch 12/100
# 6/6 - 0s - loss: 0.0236 - val_loss: 0.0439 - 85ms/epoch - 14ms/step
# Epoch 13/100
# 6/6 - 0s - loss: 0.0240 - val_loss: 0.0449 - 88ms/epoch - 15ms/step
# Epoch 14/100
# 6/6 - 0s - loss: 0.0236 - val_loss: 0.0451 - 169ms/epoch - 28ms/step
# Epoch 15/100
# 6/6 - 0s - loss: 0.0233 - val_loss: 0.0435 - 85ms/epoch - 14ms/step
# Epoch 16/100
# 6/6 - 0s - loss: 0.0226 - val_loss: 0.0424 - 86ms/epoch - 14ms/step
# Epoch 17/100
# 6/6 - 0s - loss: 0.0231 - val_loss: 0.0424 - 84ms/epoch - 14ms/step
# Epoch 18/100
# 6/6 - 0s - loss: 0.0231 - val_loss: 0.0431 - 85ms/epoch - 14ms/step
# Epoch 19/100
# 6/6 - 0s - loss: 0.0223 - val_loss: 0.0424 - 86ms/epoch - 14ms/step
# Epoch 20/100
# 6/6 - 0s - loss: 0.0230 - val_loss: 0.0419 - 88ms/epoch - 15ms/step
# Epoch 21/100
# 6/6 - 0s - loss: 0.0229 - val_loss: 0.0430 - 85ms/epoch - 14ms/step
# Epoch 22/100
# 6/6 - 0s - loss: 0.0220 - val_loss: 0.0433 - 84ms/epoch - 14ms/step
# Epoch 23/100
# 6/6 - 0s - loss: 0.0223 - val_loss: 0.0436 - 83ms/epoch - 14ms/step
# Epoch 24/100
# 6/6 - 0s - loss: 0.0218 - val_loss: 0.0437 - 84ms/epoch - 14ms/step
# Epoch 25/100
# 6/6 - 0s - loss: 0.0230 - val_loss: 0.0440 - 83ms/epoch - 14ms/step
# Epoch 26/100
# 6/6 - 0s - loss: 0.0216 - val_loss: 0.0430 - 82ms/epoch - 14ms/step
# Epoch 27/100
# 6/6 - 0s - loss: 0.0217 - val_loss: 0.0426 - 84ms/epoch - 14ms/step
# Epoch 28/100
# 6/6 - 0s - loss: 0.0213 - val_loss: 0.0432 - 82ms/epoch - 14ms/step
# Epoch 29/100
# 6/6 - 0s - loss: 0.0224 - val_loss: 0.0438 - 84ms/epoch - 14ms/step
# Epoch 30/100
# 6/6 - 0s - loss: 0.0212 - val_loss: 0.0433 - 86ms/epoch - 14ms/step
# Epoch 31/100
# 6/6 - 0s - loss: 0.0220 - val_loss: 0.0429 - 84ms/epoch - 14ms/step
# Epoch 32/100
# 6/6 - 0s - loss: 0.0220 - val_loss: 0.0428 - 81ms/epoch - 13ms/step
# Epoch 33/100
# 6/6 - 0s - loss: 0.0218 - val_loss: 0.0435 - 83ms/epoch - 14ms/step
# Epoch 34/100
# 6/6 - 0s - loss: 0.0217 - val_loss: 0.0442 - 80ms/epoch - 13ms/step
# Epoch 35/100
# 6/6 - 0s - loss: 0.0220 - val_loss: 0.0438 - 83ms/epoch - 14ms/step
# Epoch 36/100
# 6/6 - 0s - loss: 0.0218 - val_loss: 0.0438 - 78ms/epoch - 13ms/step
# Epoch 37/100
# 6/6 - 0s - loss: 0.0224 - val_loss: 0.0438 - 135ms/epoch - 22ms/step
# Epoch 38/100
# 6/6 - 0s - loss: 0.0213 - val_loss: 0.0428 - 96ms/epoch - 16ms/step
# Epoch 39/100
# 6/6 - 0s - loss: 0.0220 - val_loss: 0.0426 - 78ms/epoch - 13ms/step
# Epoch 40/100
# 6/6 - 0s - loss: 0.0225 - val_loss: 0.0443 - 80ms/epoch - 13ms/step
# Epoch 41/100
# 6/6 - 0s - loss: 0.0218 - val_loss: 0.0438 - 78ms/epoch - 13ms/step
# Epoch 42/100
# 6/6 - 0s - loss: 0.0229 - val_loss: 0.0433 - 80ms/epoch - 13ms/step
# Epoch 43/100
# 6/6 - 0s - loss: 0.0216 - val_loss: 0.0435 - 79ms/epoch - 13ms/step
# Epoch 44/100
# 6/6 - 0s - loss: 0.0230 - val_loss: 0.0435 - 80ms/epoch - 13ms/step
# Epoch 45/100
# 6/6 - 0s - loss: 0.0215 - val_loss: 0.0434 - 81ms/epoch - 14ms/step
# Epoch 46/100
# 6/6 - 0s - loss: 0.0221 - val_loss: 0.0437 - 78ms/epoch - 13ms/step
# Epoch 47/100
# 6/6 - 0s - loss: 0.0225 - val_loss: 0.0439 - 83ms/epoch - 14ms/step
# Epoch 48/100
# 6/6 - 0s - loss: 0.0221 - val_loss: 0.0434 - 87ms/epoch - 14ms/step
# Epoch 49/100
# 6/6 - 0s - loss: 0.0222 - val_loss: 0.0433 - 82ms/epoch - 14ms/step
# Epoch 50/100
# 6/6 - 0s - loss: 0.0210 - val_loss: 0.0425 - 85ms/epoch - 14ms/step
# Epoch 51/100
# 6/6 - 0s - loss: 0.0208 - val_loss: 0.0423 - 83ms/epoch - 14ms/step
# Epoch 52/100
# 6/6 - 0s - loss: 0.0214 - val_loss: 0.0425 - 79ms/epoch - 13ms/step
# Epoch 53/100
# 6/6 - 0s - loss: 0.0221 - val_loss: 0.0436 - 81ms/epoch - 14ms/step
# Epoch 54/100
# 6/6 - 0s - loss: 0.0220 - val_loss: 0.0445 - 80ms/epoch - 13ms/step
# Epoch 55/100
# 6/6 - 0s - loss: 0.0219 - val_loss: 0.0437 - 79ms/epoch - 13ms/step
# Epoch 56/100
# 6/6 - 0s - loss: 0.0216 - val_loss: 0.0426 - 138ms/epoch - 23ms/step
# Epoch 57/100
# 6/6 - 0s - loss: 0.0219 - val_loss: 0.0427 - 92ms/epoch - 15ms/step
# Epoch 58/100
# 6/6 - 0s - loss: 0.0219 - val_loss: 0.0430 - 80ms/epoch - 13ms/step
# Epoch 59/100
# 6/6 - 0s - loss: 0.0220 - val_loss: 0.0432 - 81ms/epoch - 13ms/step
# Epoch 60/100
# 6/6 - 0s - loss: 0.0212 - val_loss: 0.0430 - 79ms/epoch - 13ms/step
# Epoch 61/100
# 6/6 - 0s - loss: 0.0219 - val_loss: 0.0435 - 79ms/epoch - 13ms/step
# Epoch 62/100
# 6/6 - 0s - loss: 0.0223 - val_loss: 0.0434 - 77ms/epoch - 13ms/step
# Epoch 63/100
# 6/6 - 0s - loss: 0.0215 - val_loss: 0.0428 - 81ms/epoch - 13ms/step
# Epoch 64/100
# 6/6 - 0s - loss: 0.0218 - val_loss: 0.0435 - 81ms/epoch - 14ms/step
# Epoch 65/100
# 6/6 - 0s - loss: 0.0217 - val_loss: 0.0433 - 85ms/epoch - 14ms/step
# Epoch 66/100
# 6/6 - 0s - loss: 0.0221 - val_loss: 0.0427 - 81ms/epoch - 14ms/step
# Epoch 67/100
# 6/6 - 0s - loss: 0.0213 - val_loss: 0.0429 - 82ms/epoch - 14ms/step
# Epoch 68/100
# 6/6 - 0s - loss: 0.0217 - val_loss: 0.0434 - 82ms/epoch - 14ms/step
# Epoch 69/100
# 6/6 - 0s - loss: 0.0214 - val_loss: 0.0423 - 81ms/epoch - 14ms/step
# Epoch 70/100
# 6/6 - 0s - loss: 0.0211 - val_loss: 0.0426 - 80ms/epoch - 13ms/step
# Epoch 71/100
# 6/6 - 0s - loss: 0.0211 - val_loss: 0.0432 - 83ms/epoch - 14ms/step
# Epoch 72/100
# 6/6 - 0s - loss: 0.0210 - val_loss: 0.0430 - 79ms/epoch - 13ms/step
# Epoch 73/100
# 6/6 - 0s - loss: 0.0218 - val_loss: 0.0424 - 82ms/epoch - 14ms/step
# Epoch 74/100
# 6/6 - 0s - loss: 0.0210 - val_loss: 0.0418 - 82ms/epoch - 14ms/step
# Epoch 75/100
# 6/6 - 0s - loss: 0.0217 - val_loss: 0.0425 - 144ms/epoch - 24ms/step
# Epoch 76/100
# 6/6 - 0s - loss: 0.0207 - val_loss: 0.0432 - 89ms/epoch - 15ms/step
# Epoch 77/100
# 6/6 - 0s - loss: 0.0218 - val_loss: 0.0429 - 83ms/epoch - 14ms/step
# Epoch 78/100
# 6/6 - 0s - loss: 0.0205 - val_loss: 0.0427 - 91ms/epoch - 15ms/step
# Epoch 79/100
# 6/6 - 0s - loss: 0.0211 - val_loss: 0.0425 - 82ms/epoch - 14ms/step
# Epoch 80/100
# 6/6 - 0s - loss: 0.0214 - val_loss: 0.0421 - 83ms/epoch - 14ms/step
# Epoch 81/100
# 6/6 - 0s - loss: 0.0206 - val_loss: 0.0424 - 82ms/epoch - 14ms/step
# Epoch 82/100
# 6/6 - 0s - loss: 0.0207 - val_loss: 0.0420 - 86ms/epoch - 14ms/step
# Epoch 83/100
# 6/6 - 0s - loss: 0.0216 - val_loss: 0.0431 - 83ms/epoch - 14ms/step
# Epoch 84/100
# 6/6 - 0s - loss: 0.0220 - val_loss: 0.0436 - 84ms/epoch - 14ms/step
# Epoch 85/100
# 6/6 - 0s - loss: 0.0211 - val_loss: 0.0430 - 84ms/epoch - 14ms/step
# Epoch 86/100
# 6/6 - 0s - loss: 0.0211 - val_loss: 0.0417 - 83ms/epoch - 14ms/step
# Epoch 87/100
# 6/6 - 0s - loss: 0.0216 - val_loss: 0.0423 - 85ms/epoch - 14ms/step
# Epoch 88/100
# 6/6 - 0s - loss: 0.0213 - val_loss: 0.0425 - 84ms/epoch - 14ms/step
# Epoch 89/100
# 6/6 - 0s - loss: 0.0208 - val_loss: 0.0409 - 83ms/epoch - 14ms/step
# Epoch 90/100
# 6/6 - 0s - loss: 0.0209 - val_loss: 0.0413 - 83ms/epoch - 14ms/step
# Epoch 91/100
# 6/6 - 0s - loss: 0.0216 - val_loss: 0.0429 - 84ms/epoch - 14ms/step
# Epoch 92/100
# 6/6 - 0s - loss: 0.0216 - val_loss: 0.0425 - 82ms/epoch - 14ms/step
# Epoch 93/100
# 6/6 - 0s - loss: 0.0216 - val_loss: 0.0412 - 143ms/epoch - 24ms/step
# Epoch 94/100
# 6/6 - 0s - loss: 0.0209 - val_loss: 0.0415 - 92ms/epoch - 15ms/step
# Epoch 95/100
# 6/6 - 0s - loss: 0.0214 - val_loss: 0.0425 - 79ms/epoch - 13ms/step
# Epoch 96/100
# 6/6 - 0s - loss: 0.0209 - val_loss: 0.0425 - 82ms/epoch - 14ms/step
# Epoch 97/100
# 6/6 - 0s - loss: 0.0207 - val_loss: 0.0418 - 82ms/epoch - 14ms/step
# Epoch 98/100
# 6/6 - 0s - loss: 0.0210 - val_loss: 0.0426 - 82ms/epoch - 14ms/step
# Epoch 99/100
# 6/6 - 0s - loss: 0.0211 - val_loss: 0.0425 - 86ms/epoch - 14ms/step
# Epoch 100/100
# 6/6 - 0s - loss: 0.0207 - val_loss: 0.0412 - 81ms/epoch - 13ms/step

# %%
from numpy import concatenate
from sklearn.metrics import mean_squared_error

# %%
# make a prediction
yhat = model.predict(test_X)
print(yhat.shape)
# Out:
# 2/2 [==============================] - 1s 7ms/step
# (63, 1)

# %%
n_row=yhat.shape[0]
n_col=n_features
x = [[None for _ in range(n_col)] for _ in range(n_row)]

for i in range(0,n_row):
    for j in range(0,n_col):
        x[i][j] = yhat[i][0]
x=np.array(x)
print(x.shape)
# Out:
# (63, 3)

# %%
inv_yhat = scaler.inverse_transform(x)
inv_yhat
inv_yhat=inv_yhat[:,n_features-1]

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score

graph=dataset.tail(n_row)
graph['predict']  = inv_yhat
true_value=graph['quantity']

mape = mean_absolute_percentage_error(test_y, yhat)
R2=r2_score(test_y, yhat)

pyplot.figure(figsize=(15,5))
pyplot.plot(graph['date'] , graph['quantity'],linestyle='dashed', marker='.', label="Actual" )
pyplot.plot(graph['date'] , graph['predict'], 'r' , label="Predicted" )
pyplot.title(problem_description + '  Lead Time =' + str(n_lead) + ' ( MAPE = ' + ('%.3f' % mape) +' )' + ' ( R2 = ' + ('%.3f' % R2) +' )' , size=18)
#pyplot.xlabel('Time step', size=12)
pyplot.ylabel('Total Demand', size=16)
pyplot.legend(fontsize=14)
pyplot.xticks(fontsize=14)
pyplot.yticks(fontsize=14)
pyplot.show()
