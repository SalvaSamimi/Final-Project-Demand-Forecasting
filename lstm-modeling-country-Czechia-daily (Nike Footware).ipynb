# %%
############################ Packages
import os
import pandas as pd
import numpy as np
import datetime
from matplotlib import pyplot
import seaborn as sns
import sys 
from scipy.stats import randint
 
from sklearn.model_selection import train_test_split # to split the data into two parts
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline # pipeline making
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics # for the check the error and accuracy of the model
from sklearn.metrics import mean_squared_error,r2_score

## for Deep-learing:
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout

import warnings
warnings.filterwarnings("ignore")

# %%
orders_initial =pd.read_csv('data\df_merged.csv'  , parse_dates=['date'])
orders_initial.head()
# Out:
#         date   item_code  quantity  unit_price_vat_excl         site  \
# 0 2019-06-01  ZB00023833         1            22.326744    top4sport
# 1 2019-06-01  ZB00000154         1            10.378682  top4running
# 2 2019-06-01  ZB00007330         1            14.959302  top4running
# 3 2019-06-01  ZB00018948         1            25.594186  top4running
# 4 2019-06-01  ZB00022416         1            28.797674  top4running
#
#   country_code    brand_name   group0    group1  group2  ...  country  \
# 0           CZ  Under Armour  Apparel     Pants  Shorts  ...  Czechia
# 1           CZ          Nike  Apparel  T-Shirts     NaN  ...  Czechia
# 2           CZ          Nike  Apparel  T-Shirts     NaN  ...  Czechia
# 3           CZ          Nike  Apparel  T-Shirts    Tank  ...  Czechia
# 4           CZ          Nike  Apparel     Pants  Shorts  ...  Czechia
#
#   temperature Weather_Condition  sale_amnt month  year_month  year_week  \
# 0        19.0            Cloudy  22.326744     6     2019-06    2019-21
# 1        19.0            Cloudy  10.378682     6     2019-06    2019-21
# 2        19.0            Cloudy  14.959302     6     2019-06    2019-21
# 3        19.0            Cloudy  25.594186     6     2019-06    2019-21
# 4        19.0            Cloudy  28.797674     6     2019-06    2019-21
#
#   weekday yearweek  yearday
# 0       5       21      152
# 1       5       21      152
# 2       5       21      152
# 3       5       21      152
# 4       5       21      152
#
# [5 rows x 22 columns]

# %%
orders = orders_initial[['date','quantity','unit_price_vat_excl','weekday','month','year_month','yearweek','yearday','brand_name','group0','group1',
                         'category','country','temperature']].sort_values('date')

orders.head()
# Out:
#          date  quantity  unit_price_vat_excl  weekday  month year_month  \
# 0  2019-06-01         1            22.326744        5      6    2019-06
# 96 2019-06-01         3            26.010465        5      6    2019-06
# 95 2019-06-01         1             2.405061        5      6    2019-06
# 94 2019-06-01         2            13.628631        5      6    2019-06
# 93 2019-06-01         1             2.405061        5      6    2019-06
#
#     yearweek  yearday         brand_name     group0 group1  category  country  \
# 0         21      152       Under Armour    Apparel  Pants   fitness  Czechia
# 96        21      152             adidas  Equipment  Balls  football  Czechia
# 95        21      152  - žádný výrobce -      Other    NaN       NaN  Hungary
# 94        21      152               Nike    Apparel  Pants   running  Hungary
# 93        21      152  - žádný výrobce -      Other    NaN       NaN  Hungary
#
#     temperature
# 0          19.0
# 96         19.0
# 95         19.0
# 94         19.0
# 93         19.0

# %%
orders['country'].value_counts()
# Out:
# Czechia        706536
# Slovakia       357718
# Hungary        285658
# Romania        276361
# Germany        122508
# Spain          119064
# France          72978
# Italy           41420
# Croatia         37043
# Ireland         16581
# Denmark         14015
# Netherlands     10866
# Austria         10738
# Sweden           7596
# Portugal         4923
# Poland           4326
# Belgium          3393
# Finland          1601
# Slovenia          713
# Bulgaria            6
# Name: country, dtype: int64

# %%
#result = pd.DataFrame(orders.groupby(['date', 'weekday','group0' , 'country'], as_index=False).agg({'quantity': 'sum', 'temperature':'mean'}))
result = pd.DataFrame(orders.groupby(['date','year_month' , 'brand_name' ,'group0','weekday','country' ], as_index=False).agg({ 'temperature':'mean' , 'quantity': 'sum'  }))

######## Select Country
result = result[result['country'] == 'Czechia']
result = result[result['brand_name'] == 'Nike']
result = result[result['group0'] == 'Footwear']
dataset =result
dataset = dataset.drop(columns = ['country'])
dataset = dataset.drop(columns = ['brand_name'])
dataset = dataset.drop(columns = ['group0'])

# %%
dataset.head()
# Out:
#           date year_month  weekday  temperature  quantity
# 15  2019-06-01    2019-06        5         19.0         8
# 40  2019-06-03    2019-06        0         21.0         4
# 105 2019-06-04    2019-06        1         22.0       130
# 232 2019-06-05    2019-06        2         22.0       172
# 325 2019-06-06    2019-06        3         20.0        64

# %%
pyplot.figure(figsize=(10,8))
pyplot.subplot(2, 1, 1)
pyplot.plot(dataset['date'],dataset['quantity'])
pyplot.xticks(rotation = 0, size=10)
pyplot.yticks( size=10)
pyplot.xlabel('Date') 
pyplot.ylabel('Quantity') 
pyplot.ylim(0,250)
pyplot.show()

pyplot.figure(figsize=(10,8))
pyplot.subplot(2, 1, 2)
pyplot.plot(dataset['date'],dataset['temperature'])
pyplot.xticks(rotation = 0, size=10)
pyplot.yticks( size=10)
pyplot.xlabel('Date') 
pyplot.ylabel('temperature') 
pyplot.ylim(-10,30)
pyplot.show()

# %%
problem_description = 'Daily Prediction for Nike Footware in Czechia'

# specify the number of lag hours
n_lag = 1
n_lead = 1

# %%
############################### LSTM

from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
 # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
 # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
# put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
# drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
dataset.head()
# Out:
#           date year_month  weekday  temperature  quantity
# 15  2019-06-01    2019-06        5         19.0         8
# 40  2019-06-03    2019-06        0         21.0         4
# 105 2019-06-04    2019-06        1         22.0       130
# 232 2019-06-05    2019-06        2         22.0       172
# 325 2019-06-06    2019-06        3         20.0        64

# %%
df=dataset.iloc[:,2:]
print(df.shape)
df.head()
# Out:
# (954, 3)
#      weekday  temperature  quantity
# 15         5         19.0         8
# 40         0         21.0         4
# 105        1         22.0       130
# 232        2         22.0       172
# 325        3         20.0        64

# %%
# load dataset
values = df.values
# integer encode direction
### encoder = LabelEncoder()
### values[:,4] = encoder.fit_transform(values[:,4])

# ensure all data is float
values = values.astype('float32')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

n_features = values.shape[1]
# frame as supervised learning
reframed = series_to_supervised(scaled, n_lag, n_lead+1 )
print(reframed.shape)

reframed.head()
# Out:
# (952, 9)
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)  var1(t+1)  \
# 1   0.833333   0.789474   0.016598  0.000000  0.842105  0.000000   0.166667
# 2   0.000000   0.842105   0.000000  0.166667  0.868421  0.522822   0.333333
# 3   0.166667   0.868421   0.522822  0.333333  0.868421  0.697095   0.500000
# 4   0.333333   0.868421   0.697095  0.500000  0.815789  0.248963   0.666667
# 5   0.500000   0.815789   0.248963  0.666667  0.763158  0.124481   0.000000
#
#    var2(t+1)  var3(t+1)
# 1   0.868421   0.522822
# 2   0.868421   0.697095
# 3   0.815789   0.248963
# 4   0.763158   0.124481
# 5   0.894737   0.452282

# %%
# split into train and test sets
values = reframed.values

n_train = int(values.shape[0]*0.8)

train = values[:n_train, :]
test = values[n_train:, :]

# split into input and outputs
n_obs = ( n_lag +1 ) * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X,  test_y  =  test[:, :n_obs],  test[:, -1]
print('train: ', train_X.shape,  train_y.shape)
print('test : ',test_X.shape,  test_y.shape)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_lag + 1 , n_features))
test_X = test_X.reshape((test_X.shape[0], n_lag + 1, n_features))
print('train: ', train_X.shape, train_y.shape)
print('test : ', test_X.shape, test_y.shape)
# Out:
# train:  (761, 6) (761,)
# test :  (191, 6) (191,)
# train:  (761, 2, 3) (761,)
# test :  (191, 2, 3) (191,)

# %%
# design network 
model = Sequential()
model.add(LSTM(70, return_sequences=True , input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(70))
model.add(Dropout(0.1))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# fit network
n_epochs=100
history = model.fit(train_X, train_y, epochs=n_epochs, batch_size=50, 
                    validation_data=(test_X, test_y), verbose=2, shuffle=False )

# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.ylim(0,.04)
pyplot.xlabel('Epoch') 
pyplot.ylabel('Loss') 
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# 16/16 - 6s - loss: 0.0511 - val_loss: 0.0089 - 6s/epoch - 376ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.0183 - val_loss: 0.0077 - 155ms/epoch - 10ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.0166 - val_loss: 0.0078 - 149ms/epoch - 9ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.0147 - val_loss: 0.0070 - 147ms/epoch - 9ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.0140 - val_loss: 0.0069 - 150ms/epoch - 9ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.0125 - val_loss: 0.0067 - 149ms/epoch - 9ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.0120 - val_loss: 0.0067 - 151ms/epoch - 9ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.0110 - val_loss: 0.0068 - 153ms/epoch - 10ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.0103 - val_loss: 0.0069 - 149ms/epoch - 9ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.0100 - val_loss: 0.0070 - 147ms/epoch - 9ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.0098 - val_loss: 0.0070 - 149ms/epoch - 9ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.0097 - val_loss: 0.0068 - 147ms/epoch - 9ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.0099 - val_loss: 0.0067 - 146ms/epoch - 9ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.0093 - val_loss: 0.0067 - 149ms/epoch - 9ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.0093 - val_loss: 0.0066 - 147ms/epoch - 9ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.0096 - val_loss: 0.0065 - 148ms/epoch - 9ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.0098 - val_loss: 0.0065 - 148ms/epoch - 9ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.0092 - val_loss: 0.0064 - 149ms/epoch - 9ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.0091 - val_loss: 0.0063 - 212ms/epoch - 13ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.0091 - val_loss: 0.0063 - 147ms/epoch - 9ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.0092 - val_loss: 0.0062 - 146ms/epoch - 9ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.0091 - val_loss: 0.0062 - 147ms/epoch - 9ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.0090 - val_loss: 0.0061 - 144ms/epoch - 9ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.0094 - val_loss: 0.0061 - 145ms/epoch - 9ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.0090 - val_loss: 0.0061 - 142ms/epoch - 9ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.0091 - val_loss: 0.0061 - 143ms/epoch - 9ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.0090 - val_loss: 0.0061 - 141ms/epoch - 9ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.0088 - val_loss: 0.0060 - 163ms/epoch - 10ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.0088 - val_loss: 0.0060 - 142ms/epoch - 9ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.0091 - val_loss: 0.0060 - 143ms/epoch - 9ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.0091 - val_loss: 0.0060 - 144ms/epoch - 9ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.0089 - val_loss: 0.0059 - 145ms/epoch - 9ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.0090 - val_loss: 0.0059 - 163ms/epoch - 10ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.0090 - val_loss: 0.0059 - 143ms/epoch - 9ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.0087 - val_loss: 0.0059 - 144ms/epoch - 9ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.0089 - val_loss: 0.0059 - 144ms/epoch - 9ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.0085 - val_loss: 0.0058 - 143ms/epoch - 9ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.0086 - val_loss: 0.0058 - 148ms/epoch - 9ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.0087 - val_loss: 0.0058 - 149ms/epoch - 9ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.0086 - val_loss: 0.0058 - 141ms/epoch - 9ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.0089 - val_loss: 0.0058 - 141ms/epoch - 9ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.0082 - val_loss: 0.0058 - 146ms/epoch - 9ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.0085 - val_loss: 0.0057 - 142ms/epoch - 9ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.0085 - val_loss: 0.0057 - 140ms/epoch - 9ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.0089 - val_loss: 0.0057 - 141ms/epoch - 9ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.0086 - val_loss: 0.0056 - 144ms/epoch - 9ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.0083 - val_loss: 0.0056 - 143ms/epoch - 9ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.0085 - val_loss: 0.0056 - 142ms/epoch - 9ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.0084 - val_loss: 0.0056 - 154ms/epoch - 10ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.0084 - val_loss: 0.0056 - 141ms/epoch - 9ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.0088 - val_loss: 0.0056 - 142ms/epoch - 9ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 0.0083 - val_loss: 0.0056 - 141ms/epoch - 9ms/step
# Epoch 53/100
# 16/16 - 0s - loss: 0.0082 - val_loss: 0.0055 - 142ms/epoch - 9ms/step
# Epoch 54/100
# 16/16 - 0s - loss: 0.0084 - val_loss: 0.0055 - 140ms/epoch - 9ms/step
# Epoch 55/100
# 16/16 - 0s - loss: 0.0082 - val_loss: 0.0055 - 143ms/epoch - 9ms/step
# Epoch 56/100
# 16/16 - 0s - loss: 0.0083 - val_loss: 0.0054 - 141ms/epoch - 9ms/step
# Epoch 57/100
# 16/16 - 0s - loss: 0.0082 - val_loss: 0.0055 - 142ms/epoch - 9ms/step
# Epoch 58/100
# 16/16 - 0s - loss: 0.0082 - val_loss: 0.0054 - 142ms/epoch - 9ms/step
# Epoch 59/100
# 16/16 - 0s - loss: 0.0084 - val_loss: 0.0054 - 148ms/epoch - 9ms/step
# Epoch 60/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0054 - 141ms/epoch - 9ms/step
# Epoch 61/100
# 16/16 - 0s - loss: 0.0081 - val_loss: 0.0054 - 143ms/epoch - 9ms/step
# Epoch 62/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0053 - 145ms/epoch - 9ms/step
# Epoch 63/100
# 16/16 - 0s - loss: 0.0081 - val_loss: 0.0053 - 301ms/epoch - 19ms/step
# Epoch 64/100
# 16/16 - 0s - loss: 0.0082 - val_loss: 0.0053 - 231ms/epoch - 14ms/step
# Epoch 65/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0053 - 169ms/epoch - 11ms/step
# Epoch 66/100
# 16/16 - 0s - loss: 0.0081 - val_loss: 0.0053 - 174ms/epoch - 11ms/step
# Epoch 67/100
# 16/16 - 0s - loss: 0.0078 - val_loss: 0.0053 - 141ms/epoch - 9ms/step
# Epoch 68/100
# 16/16 - 0s - loss: 0.0081 - val_loss: 0.0053 - 292ms/epoch - 18ms/step
# Epoch 69/100
# 16/16 - 0s - loss: 0.0084 - val_loss: 0.0053 - 219ms/epoch - 14ms/step
# Epoch 70/100
# 16/16 - 0s - loss: 0.0082 - val_loss: 0.0053 - 164ms/epoch - 10ms/step
# Epoch 71/100
# 16/16 - 0s - loss: 0.0084 - val_loss: 0.0052 - 143ms/epoch - 9ms/step
# Epoch 72/100
# 16/16 - 0s - loss: 0.0079 - val_loss: 0.0053 - 148ms/epoch - 9ms/step
# Epoch 73/100
# 16/16 - 0s - loss: 0.0081 - val_loss: 0.0053 - 233ms/epoch - 15ms/step
# Epoch 74/100
# 16/16 - 0s - loss: 0.0079 - val_loss: 0.0053 - 221ms/epoch - 14ms/step
# Epoch 75/100
# 16/16 - 0s - loss: 0.0084 - val_loss: 0.0052 - 173ms/epoch - 11ms/step
# Epoch 76/100
# 16/16 - 0s - loss: 0.0081 - val_loss: 0.0052 - 142ms/epoch - 9ms/step
# Epoch 77/100
# 16/16 - 0s - loss: 0.0078 - val_loss: 0.0052 - 142ms/epoch - 9ms/step
# Epoch 78/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0052 - 145ms/epoch - 9ms/step
# Epoch 79/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0052 - 141ms/epoch - 9ms/step
# Epoch 80/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0052 - 143ms/epoch - 9ms/step
# Epoch 81/100
# 16/16 - 0s - loss: 0.0077 - val_loss: 0.0052 - 140ms/epoch - 9ms/step
# Epoch 82/100
# 16/16 - 0s - loss: 0.0077 - val_loss: 0.0052 - 142ms/epoch - 9ms/step
# Epoch 83/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0051 - 141ms/epoch - 9ms/step
# Epoch 84/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0051 - 144ms/epoch - 9ms/step
# Epoch 85/100
# 16/16 - 0s - loss: 0.0079 - val_loss: 0.0051 - 142ms/epoch - 9ms/step
# Epoch 86/100
# 16/16 - 0s - loss: 0.0077 - val_loss: 0.0051 - 142ms/epoch - 9ms/step
# Epoch 87/100
# 16/16 - 0s - loss: 0.0076 - val_loss: 0.0051 - 143ms/epoch - 9ms/step
# Epoch 88/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0051 - 139ms/epoch - 9ms/step
# Epoch 89/100
# 16/16 - 0s - loss: 0.0079 - val_loss: 0.0051 - 143ms/epoch - 9ms/step
# Epoch 90/100
# 16/16 - 0s - loss: 0.0078 - val_loss: 0.0050 - 145ms/epoch - 9ms/step
# Epoch 91/100
# 16/16 - 0s - loss: 0.0079 - val_loss: 0.0051 - 145ms/epoch - 9ms/step
# Epoch 92/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0050 - 141ms/epoch - 9ms/step
# Epoch 93/100
# 16/16 - 0s - loss: 0.0079 - val_loss: 0.0051 - 144ms/epoch - 9ms/step
# Epoch 94/100
# 16/16 - 0s - loss: 0.0078 - val_loss: 0.0050 - 144ms/epoch - 9ms/step
# Epoch 95/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0050 - 146ms/epoch - 9ms/step
# Epoch 96/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0050 - 145ms/epoch - 9ms/step
# Epoch 97/100
# 16/16 - 0s - loss: 0.0081 - val_loss: 0.0050 - 145ms/epoch - 9ms/step
# Epoch 98/100
# 16/16 - 0s - loss: 0.0081 - val_loss: 0.0050 - 145ms/epoch - 9ms/step
# Epoch 99/100
# 16/16 - 0s - loss: 0.0080 - val_loss: 0.0050 - 146ms/epoch - 9ms/step
# Epoch 100/100
# 16/16 - 0s - loss: 0.0075 - val_loss: 0.0050 - 148ms/epoch - 9ms/step

# %%
from numpy import concatenate
from sklearn.metrics import mean_squared_error

# %%
# make a prediction
yhat = model.predict(test_X)
print(yhat.shape)
# Out:
# 6/6 [==============================] - 1s 4ms/step
# (191, 1)

# %%
n_row=yhat.shape[0]
n_col=n_features
x = [[None for _ in range(n_col)] for _ in range(n_row)]

for i in range(0,n_row):
    for j in range(0,n_col):
        x[i][j] = yhat[i][0]
x=np.array(x)
print(x.shape)
# Out:
# (191, 3)

# %%
inv_yhat = scaler.inverse_transform(x)
inv_yhat
inv_yhat=inv_yhat[:,n_features-1]

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score

graph=dataset.tail(n_row)
graph['predict']  = inv_yhat
true_value=graph['quantity']

mape = mean_absolute_percentage_error(test_y, yhat)
R2=r2_score(test_y, yhat)

pyplot.figure(figsize=(15,5))
pyplot.plot(graph['date'] , graph['quantity'],linestyle='dashed', marker='.', label="Actual" )
pyplot.plot(graph['date'] , graph['predict'], 'r' , label="Predicted" )
pyplot.title(problem_description + '  Lead Time =' + str(n_lead) + ' ( MAPE = ' + ('%.3f' % mape) +' )' + ' ( R2 = ' + ('%.3f' % R2) +' )' , size=18)
#pyplot.xlabel('Time step', size=12)
pyplot.ylabel('Total Demand', size=16)
pyplot.legend(fontsize=14)
pyplot.xticks(fontsize=14)
pyplot.yticks(fontsize=14)
pyplot.show()
